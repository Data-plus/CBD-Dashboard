# %% [markdown]
# ## Import Libraries

# %%
from pymongo import MongoClient
import json
from bson import ObjectId

# %%
import pprint

# %%
MONGODB_HOST = 'localhost'
MONGODB_PORT = 27017
DBS_NAME = 'mydb'
COLLECTION_NAME = 'projects'
FIELDS = "FeatureCollection"

# %%
def dashboard_projects():
    connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
    collection = connection[DBS_NAME][COLLECTION_NAME]
    projects = collection.find_one({"type": "FeatureCollection"}, {"_id":0})

    return projects

# %%
dashboard_projects()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.965463853978, -37.8077644149636]},
#    'properties': {'FIELD1': 0,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Old Melbourne Gaol Crime & Justice Experience'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.953478052064, -37.8242574266145]},
#    'properties': {'FIELD1': 1,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Polly Woodside'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.967252924593, -37.8266045432686]},
#    'properties': {'FIELD1': 2,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Australian Centre for Contemporary Art'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.968837288153, -37.8219947335768]},
#    'properties': {'FIELD1': 3,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Victorian Arts Centre'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.969899048343, -37.8174831423197]},
#    'properties': {'FIELD1': 4,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Ian Potter Centre: NGV Australia'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.9839700954, -37.8188662730911]},
#    'properties': {'FIELD1': 5,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Thoroughbred Racing Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.948496661709, -37.8213744301481]},
#    'properties': {'FIELD1': 6,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Fox Classic Car Collection'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.971690718887, -37.8035518129299]},
#    'properties': {'FIELD1': 7,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Melbourne Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.984669809381, -37.8189544909462]},
#    'properties': {'FIELD1': 8,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'National Sports Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.980554992725, -37.8145407488014]},
#    'properties': {'FIELD1': 9,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': "Sinclair's Cottage"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.954039975197, -37.8222182774409]},
#    'properties': {'FIELD1': 10,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Victoria Police Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.960426777129, -37.8191798798062]},
#    'properties': {'FIELD1': 11,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Immigration Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.975373745366, -37.8085761281612]},
#    'properties': {'FIELD1': 12,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Fire Services Museum Victoria'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.964156669702, -37.7973939595503]},
#    'properties': {'FIELD1': 13,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Ian Potter Museum Of Art'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.954027907736, -37.8133854259085]},
#    'properties': {'FIELD1': 14,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Koorie Heritage Trust Inc'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.979471339826, -37.8144604899837]},
#    'properties': {'FIELD1': 15,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': "Cooks' Cottage"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.971521914952, -37.80460262432]},
#    'properties': {'FIELD1': 16,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Royal Exhibition Building'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.969070431323, -37.8176107327202]},
#    'properties': {'FIELD1': 17,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Australian Centre For The Moving Image (ACMI)'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96923385414, -37.8107686127655]},
#    'properties': {'FIELD1': 18,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Museum Of Australian Chinese History'}}]}

# %%
# Call all documents
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
projects2 = collection.find_one({"type": "FeatureCollection"}, {"_id":0})

# %%
client = MongoClient()
db = client.mydb
collection = db.projects

# %%
from bson.son import SON
from pymongo import MongoClient

db = MongoClient()
latitude = -37.44609999
longitude = 144.96923385414
max_distance = 1000 #meters

# %%
location = [144.965234, -37.8076]

# %%
db.collection.drop_indexes()

# %%
for idx in db.collection.list_indexes():
    print (idx)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_'), ('ns', 'mydb.collection')])

# %%
db.collection.create_index([( "features.geometry.coordinates", "2dsphere" )])
# Out:
# 'features.geometry.coordinates_2dsphere'

# %%
## Unwind search

pipeline = [{"$unwind": "$features"},
            {"$match":{'features.geometry.coordinates':[144.965463853978, -37.8077644149636]}},
            {"$group": {"_id": "$features"}}]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# []

# %%
pipeline2 = [{"$unwind": "$features"},
            {"$match":{'features.properties.Sub Theme' : 'Art Gallery/Museum'}},
            {"$group": {"_id": "$features"}}]

pprint.pprint(list(collection.aggregate(pipeline2)))
# Out:
# [{'_id': {'geometry': {'coordinates': [144.969070431323, -37.8176107327202],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 17,
#                          'Feature Name': 'Australian Centre For The Moving '
#                                          'Image (ACMI)',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.971521914952, -37.80460262432],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 16,
#                          'Feature Name': 'Royal Exhibition Building',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.979471339826, -37.8144604899837],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 15,
#                          'Feature Name': "Cooks' Cottage",
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.975373745366, -37.8085761281612],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 12,
#                          'Feature Name': 'Fire Services Museum Victoria',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.960426777129, -37.8191798798062],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 11,
#                          'Feature Name': 'Immigration Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.980554992725, -37.8145407488014],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 9,
#                          'Feature Name': "Sinclair's Cottage",
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.954027907736, -37.8133854259085],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 14,
#                          'Feature Name': 'Koorie Heritage Trust Inc',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.984669809381, -37.8189544909462],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 8,
#                          'Feature Name': 'National Sports Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.9839700954, -37.8188662730911],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 5,
#                          'Feature Name': 'Thoroughbred Racing Gallery',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.967252924593, -37.8266045432686],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 2,
#                          'Feature Name': 'Australian Centre for Contemporary '
#                                          'Art',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.968837288153, -37.8219947335768],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 3,
#                          'Feature Name': 'Victorian Arts Centre',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.953478052064, -37.8242574266145],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 1,
#                          'Feature Name': 'Polly Woodside',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.948496661709, -37.8213744301481],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 6,
#                          'Feature Name': 'Fox Classic Car Collection',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.964156669702, -37.7973939595503],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 13,
#                          'Feature Name': 'The Ian Potter Museum Of Art',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.969899048343, -37.8174831423197],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 4,
#                          'Feature Name': 'The Ian Potter Centre: NGV Australia',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.971690718887, -37.8035518129299],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 7,
#                          'Feature Name': 'Melbourne Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.954039975197, -37.8222182774409],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 10,
#                          'Feature Name': 'Victoria Police Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.96923385414, -37.8107686127655],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 18,
#                          'Feature Name': 'The Museum Of Australian Chinese '
#                                          'History',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.965463853978, -37.8077644149636],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 0,
#                          'Feature Name': 'Old Melbourne Gaol Crime & Justice '
#                                          'Experience',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}}]

# %% [markdown]
# ## Working code

# %%
pipeline = [
        {'$geoNear': {
            'near' : { 'type' : "Point", 'coordinates' : location },
             'distanceField': "dist.calculated",
             'maxDistance': 100,
             'includeLocs': "dist.location",
              'key': 'features.geometry.coordinates',
             'uniqueDocs': False,
             'spherical': True}},
    { "$unwind" : "$features" },
    { "$redact" : {   
        "$cond" : {
            "if" : { "$eq" : [ { "$cmp" : [ "$features.geometry.coordinates", "$dist.location" ] }, 0 ] },
            "then" : "$$KEEP",
            "else" : "$$PRUNE"
        }
    }
}
]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('5ca63a65122b9a6192720138'),
#   'dist': {'calculated': 27.27001406965783,
#            'location': [144.965463853978, -37.8077644149636]},
#   'features': {'geometry': {'coordinates': [144.965463853978,
#                                             -37.8077644149636],
#                             'type': 'Point'},
#                'properties': {'FIELD1': 0,
#                               'Feature Name': 'Old Melbourne Gaol Crime & '
#                                               'Justice Experience',
#                               'Sub Theme': 'Art Gallery/Museum',
#                               'Theme': 'Place Of Assembly'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %% [markdown]
# ### Check

# %%
a1 = [144.9654, -37.8076]
a2 = [144.9656988, -37.80619915]

distance_finder(a1, a2)
# Out:
# 157.69509130741474 m

# %% [markdown]
# ## Implement Automation

# %%
click = [144.9607616045045, -37.811441609877804]

# %%
location = [144.965234, -37.8076]

# %%
pipeline = [
        {'$geoNear': {
            'near' : { 'type' : "Point", 'coordinates' : click },
             'distanceField': "dist.calculated",
             'maxDistance': 500,
             'includeLocs': "dist.location",
              'key': 'features.geometry.coordinates',
             'uniqueDocs': False,
             'spherical': True}},
    { "$unwind" : "$features" },
    { "$redact" : {   
        "$cond" : {
            "if" : { "$eq" : [ { "$cmp" : [ "$features.geometry.coordinates", "$dist.location" ] }, 0 ] },
            "then" : "$$KEEP",
            "else" : "$$PRUNE"
        }
    }
}
]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('5cb0a55fe39a5cbeb4a206d7'),
#   'dist': {'calculated': 68.10091452076718,
#            'location': [144.9602499, -37.81190077]},
#   'features': {'geometry': {'coordinates': [144.9602499, -37.81190077],
#                             'type': 'Point'},
#                'properties': {'Base property ID': 106018,
#                               'Block ID': 74,
#                               'CLUE small area': 'Melbourne (CBD)',
#                               'Census year': 2015,
#                               'FIELD1': 67,
#                               'Industry (ANZSIC4) code': 4520,
#                               'Industry (ANZSIC4) description': 'Pubs, Taverns '
#                                                                 'and Bars',
#                               'Number of seats': 50,
#                               'Property ID': 106018,
#                               'Seating type': 'Seats - Indoor',
#                               'Street address': '395-397 Little Lonsdale '
#                                                 'Street',
#                               'Trading name': 'Horse Bazaar'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5cbb067ae39a5cbeb4a82260'),
#   'dist': {'calculated': 121.56627721390748,
#            'location': [144.9615331, -37.81234775]},
#   'features': {'geometry': {'coordinates': [144.9615331, -37.81234775],
#                             'type': 'Point'},
#                'properties': {'direction_1': 'East',
#                               'direction_2': 'West',
#                               'installation_date': '25/07/2018',
#                               'note': '',
#                               'sensor_description': 'Lonsdale St - Elizabeth '
#                                                     'St (North)',
#                               'sensor_id': 56,
#                               'sensor_name': 'Lon364_T',
#                               'status': 'A'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %%
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
pprint.pprint(list(collection.aggregate(pipeline)))
connection.close()
# Out:
# [{'_id': ObjectId('5cb0a55fe39a5cbeb4a206d7'),
#   'dist': {'calculated': 68.10091452076718,
#            'location': [144.9602499, -37.81190077]},
#   'features': {'geometry': {'coordinates': [144.9602499, -37.81190077],
#                             'type': 'Point'},
#                'properties': {'Base property ID': 106018,
#                               'Block ID': 74,
#                               'CLUE small area': 'Melbourne (CBD)',
#                               'Census year': 2015,
#                               'FIELD1': 67,
#                               'Industry (ANZSIC4) code': 4520,
#                               'Industry (ANZSIC4) description': 'Pubs, Taverns '
#                                                                 'and Bars',
#                               'Number of seats': 50,
#                               'Property ID': 106018,
#                               'Seating type': 'Seats - Indoor',
#                               'Street address': '395-397 Little Lonsdale '
#                                                 'Street',
#                               'Trading name': 'Horse Bazaar'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5cbb067ae39a5cbeb4a82260'),
#   'dist': {'calculated': 121.56627721390748,
#            'location': [144.9615331, -37.81234775]},
#   'features': {'geometry': {'coordinates': [144.9615331, -37.81234775],
#                             'type': 'Point'},
#                'properties': {'direction_1': 'East',
#                               'direction_2': 'West',
#                               'installation_date': '25/07/2018',
#                               'note': '',
#                               'sensor_description': 'Lonsdale St - Elizabeth '
#                                                     'St (North)',
#                               'sensor_id': 56,
#                               'sensor_name': 'Lon364_T',
#                               'status': 'A'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %%
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
finding = collection.find_one( { "_id": ObjectId('5cc683b30e00cbd80dd912ad') }, {"_id":0})
connection.close()
finding
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9651532, -37.8134944]},
#    'properties': {'sensor_id': 1,
#     'sensor_description': 'Bourke Street Mall (North)',
#     'sensor_name': 'Bou292_T',
#     'installation_date': '24/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9651672, -37.81380667]},
#    'properties': {'sensor_id': 2,
#     'sensor_description': 'Bourke Street Mall (South)',
#     'sensor_name': 'Bou283_T',
#     'installation_date': '30/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9642949, -37.81101523]},
#    'properties': {'sensor_id': 3,
#     'sensor_description': 'Melbourne Central',
#     'sensor_name': 'Swa295_T',
#     'installation_date': '25/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9660878, -37.81487988]},
#    'properties': {'sensor_id': 4,
#     'sensor_description': 'Town Hall (West)',
#     'sensor_name': 'Swa123_T',
#     'installation_date': '23/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9678766, -37.81874249]},
#    'properties': {'sensor_id': 5,
#     'sensor_description': 'Princes Bridge',
#     'sensor_name': 'PriNW_T',
#     'installation_date': '26/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9655826, -37.81911704]},
#    'properties': {'sensor_id': 6,
#     'sensor_description': 'Flinders Street Station Underpass',
#     'sensor_name': 'FliS_T',
#     'installation_date': '25/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9714148, -37.81832375]},
#    'properties': {'sensor_id': 7,
#     'sensor_description': 'Birrarung Marr',
#     'sensor_name': 'Fed_T',
#     'installation_date': '17/12/2014',
#     'status': 'I',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9471751, -37.82293543]},
#    'properties': {'sensor_id': 8,
#     'sensor_description': 'Webb Bridge',
#     'sensor_name': 'WebBN_T',
#     'installation_date': '24/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9510256, -37.81982992]},
#    'properties': {'sensor_id': 9,
#     'sensor_description': 'Southern Cross Station',
#     'sensor_name': 'Col700_T',
#     'installation_date': '23/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9471055, -37.81876473]},
#    'properties': {'sensor_id': 10,
#     'sensor_description': 'Victoria Point',
#     'sensor_name': 'BouHbr_T',
#     'installation_date': '23/04/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.939707, -37.81564989]},
#    'properties': {'sensor_id': 11,
#     'sensor_description': 'Waterfront City',
#     'sensor_name': 'WatCit_T',
#     'installation_date': '20/01/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.942924, -37.81457987]},
#    'properties': {'sensor_id': 12,
#     'sensor_description': 'New Quay',
#     'sensor_name': 'NewQ_T',
#     'installation_date': '21/01/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9565265, -37.81239679]},
#    'properties': {'sensor_id': 13,
#     'sensor_description': 'Flagstaff Station',
#     'sensor_name': 'Wil277_T',
#     'installation_date': '24/03/2009',
#     'status': 'I',
#     'note': '',
#     'direction_1': '',
#     'direction_2': ''}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.962919, -37.82011242]},
#    'properties': {'sensor_id': 14,
#     'sensor_description': 'Sandridge Bridge',
#     'sensor_name': 'SanBri_T',
#     'installation_date': '24/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9644713, -37.81064378]},
#    'properties': {'sensor_id': 15,
#     'sensor_description': 'State Library',
#     'sensor_name': 'QV_T',
#     'installation_date': '25/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9732359, -37.81362542]},
#    'properties': {'sensor_id': 17,
#     'sensor_description': 'Collins Place (South)',
#     'sensor_name': 'Col15_T',
#     'installation_date': '30/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9730535, -37.81344861]},
#    'properties': {'sensor_id': 18,
#     'sensor_description': 'Collins Place (North)',
#     'sensor_name': 'Col12_T',
#     'installation_date': '30/03/2009',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9655067, -37.81237202]},
#    'properties': {'sensor_id': 19,
#     'sensor_description': 'Chinatown-Swanston St (North)',
#     'sensor_name': 'LtB210_T',
#     'installation_date': '02/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9682466, -37.81172913]},
#    'properties': {'sensor_id': 20,
#     'sensor_description': 'Chinatown-Lt Bourke St (South)',
#     'sensor_name': 'LtB170_T',
#     'installation_date': '06/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9677876, -37.81244703]},
#    'properties': {'sensor_id': 21,
#     'sensor_description': 'Bourke St-Russell St (West)',
#     'sensor_name': 'Rus180_T',
#     'installation_date': '02/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9650682, -37.81786445]},
#    'properties': {'sensor_id': 22,
#     'sensor_description': 'Flinders St-Elizabeth St (East)',
#     'sensor_name': 'Eli274_T',
#     'installation_date': '12/08/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9545275, -37.81909256]},
#    'properties': {'sensor_id': 23,
#     'sensor_description': 'Spencer St-Collins St (South)',
#     'sensor_name': 'Col623_T',
#     'installation_date': '02/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.954492, -37.81887962]},
#    'properties': {'sensor_id': 24,
#     'sensor_description': 'Spencer St-Collins St (North)',
#     'sensor_name': 'Col620_T',
#     'installation_date': '02/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9560443, -37.82401776]},
#    'properties': {'sensor_id': 25,
#     'sensor_description': 'Melbourne Convention Exhibition Centre',
#     'sensor_name': 'MCEC_T',
#     'installation_date': '28/08/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.960494, -37.80869542]},
#    'properties': {'sensor_id': 26,
#     'sensor_description': 'QV Market-Elizabeth St (West)',
#     'sensor_name': 'Eli483_T',
#     'installation_date': '28/09/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9564469, -37.80606888]},
#    'properties': {'sensor_id': 27,
#     'sensor_description': 'QV Market-Peel St',
#     'sensor_name': 'Vic_T',
#     'installation_date': '16/08/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9687931, -37.82129924]},
#    'properties': {'sensor_id': 28,
#     'sensor_description': 'The Arts Centre',
#     'sensor_name': 'VAC_T',
#     'installation_date': '23/08/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9686345, -37.81965808]},
#    'properties': {'sensor_id': 29,
#     'sensor_description': 'St Kilda Rd-Alexandra Gardens',
#     'sensor_name': 'AG_T',
#     'installation_date': '11/10/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9665681, -37.81121849]},
#    'properties': {'sensor_id': 30,
#     'sensor_description': 'Lonsdale St (South)',
#     'sensor_name': 'Lon189_T',
#     'installation_date': '14/10/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9665891, -37.8016968]},
#    'properties': {'sensor_id': 31,
#     'sensor_description': 'Lygon St (West)',
#     'sensor_name': 'Lyg161_T',
#     'installation_date': '10/10/2013',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9745406, -37.81483252]},
#    'properties': {'sensor_id': 33,
#     'sensor_description': 'Flinders St-Spring St (West)',
#     'sensor_name': 'Spr13_T',
#     'installation_date': '23/04/2014',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9741505, -37.81537985]},
#    'properties': {'sensor_id': 34,
#     'sensor_description': 'Flinders St-Spark La',
#     'sensor_name': 'Fli32_T',
#     'installation_date': '08/06/2014',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9650888, -37.82017828]},
#    'properties': {'sensor_id': 35,
#     'sensor_description': 'Southbank',
#     'sensor_name': 'SouthB_T',
#     'installation_date': '11/04/2016',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9612106, -37.81652527]},
#    'properties': {'sensor_id': 36,
#     'sensor_description': 'Queen St (West)',
#     'sensor_name': 'Que85_T',
#     'installation_date': '20/01/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9667145, -37.80310271]},
#    'properties': {'sensor_id': 37,
#     'sensor_description': 'Lygon St (East)',
#     'sensor_name': 'Lyg260_T',
#     'installation_date': '11/02/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699575, -37.81379749]},
#    'properties': {'sensor_id': 39,
#     'sensor_description': 'Alfred Place',
#     'sensor_name': 'AlfPl_T',
#     'installation_date': '27/08/2014',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9722759, -37.80999341]},
#    'properties': {'sensor_id': 40,
#     'sensor_description': 'Lonsdale St-Spring St (West)',
#     'sensor_name': 'Spr201_T',
#     'installation_date': '19/01/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9668973, -37.81668633]},
#    'properties': {'sensor_id': 41,
#     'sensor_description': 'Flinders La-Swanston St (West)',
#     'sensor_name': 'Swa31',
#     'installation_date': '29/06/2017',
#     'status': 'I',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9638641, -37.80008565]},
#    'properties': {'sensor_id': 42,
#     'sensor_description': 'Grattan St-Swanston St (West)',
#     'sensor_name': 'UM1_T',
#     'installation_date': '15/04/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9641178, -37.79844525]},
#    'properties': {'sensor_id': 43,
#     'sensor_description': 'Monash Rd-Swanston St (West)',
#     'sensor_name': 'UM2_T',
#     'installation_date': '15/04/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9644038, -37.79690473]},
#    'properties': {'sensor_id': 44,
#     'sensor_description': 'Tin Alley-Swanston St (West)',
#     'sensor_name': 'UM3_T',
#     'installation_date': '15/04/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9660938, -37.81414074]},
#    'properties': {'sensor_id': 45,
#     'sensor_description': 'Little Collins St-Swanston St (East)',
#     'sensor_name': 'Swa148_T',
#     'installation_date': '29/06/2017',
#     'status': 'I',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9615673, -37.80240719]},
#    'properties': {'sensor_id': 46,
#     'sensor_description': 'Pelham St (South)',
#     'sensor_name': 'Pel147_T',
#     'installation_date': '10/07/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9622008, -37.81160331]},
#    'properties': {'sensor_id': 47,
#     'sensor_description': 'Melbourne Central-Elizabeth St (East)Melbourne Central-Elizabeth St (East)',
#     'sensor_name': 'Eli250_T',
#     'installation_date': '24/08/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.958667, -37.80631581]},
#    'properties': {'sensor_id': 48,
#     'sensor_description': 'QVM-Queen St (East)',
#     'sensor_name': 'QVMQ_T',
#     'installation_date': '02/10/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9595606, -37.80730067]},
#    'properties': {'sensor_id': 49,
#     'sensor_description': 'QVM-Therry St (South)',
#     'sensor_name': 'Eli501_T',
#     'installation_date': '29/11/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9672101, -37.79808191]},
#    'properties': {'sensor_id': 50,
#     'sensor_description': 'Faraday St-Lygon St (West)',
#     'sensor_name': 'Lyg309_T',
#     'installation_date': '30/11/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9590632, -37.80841814]},
#    'properties': {'sensor_id': 51,
#     'sensor_description': 'QVM-Franklin St (North)',
#     'sensor_name': 'Fra118_T',
#     'installation_date': '30/11/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9619401, -37.81252157]},
#    'properties': {'sensor_id': 52,
#     'sensor_description': 'Elizabeth St-Lonsdale St (South)',
#     'sensor_name': 'Eli263_T',
#     'installation_date': '31/07/2017',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.965499, -37.8156419]},
#    'properties': {'sensor_id': 53,
#     'sensor_description': 'Collins Street (North)',
#     'sensor_name': 'Col254_T',
#     'installation_date': '23/09/2015',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.963084, -37.804024]},
#    'properties': {'sensor_id': 54,
#     'sensor_description': 'Lincoln-Swanston (West)',
#     'sensor_name': 'Swa607_T',
#     'installation_date': '26/06/2018',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9614234, -37.81006172]},
#    'properties': {'sensor_id': 55,
#     'sensor_description': 'Elizabeth St-La Trobe St (East)',
#     'sensor_name': 'Eli368_T',
#     'installation_date': '19/07/2018',
#     'status': 'I',
#     'note': '',
#     'direction_1': 'South',
#     'direction_2': 'North'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9615331, -37.81234775]},
#    'properties': {'sensor_id': 56,
#     'sensor_description': 'Lonsdale St - Elizabeth St (North)',
#     'sensor_name': 'Lon364_T',
#     'installation_date': '25/07/2018',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.950256, -37.8176735]},
#    'properties': {'sensor_id': 57,
#     'sensor_description': 'Bourke St Bridge',
#     'sensor_name': 'BouBri_T',
#     'installation_date': '13/08/2018',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9535808, -37.81686074]},
#    'properties': {'sensor_id': 58,
#     'sensor_description': 'Bourke St - Spencer St (North)',
#     'sensor_name': 'Bou688_T',
#     'installation_date': '27/09/2018',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'West',
#     'direction_2': 'East'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9630486, -37.80825648]},
#    'properties': {'sensor_id': 59,
#     'sensor_description': 'Building 80 RMIT',
#     'sensor_name': 'RMIT_T',
#     'installation_date': '13/02/2019',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'North',
#     'direction_2': 'South'}}]}

# %%
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
finding = collection.find_one()
connection.close()
finding
# Out:
# {'_id': ObjectId('5ca5a19f9a2c9b0218cbb6e5'),
#  'school state': 'NY',
#  'resource type': 'Books',
#  'poverty level': 'highest poverty',
#  'highest poverty': 308,
#  'total donations': 'competed',
#  'date posted': '08/03/2007'}

# %%
def prt(pipeline):
    return list(collection.aggregate(pipeline))

# %%
prt(pipeline)
# Out:
# [{'_id': ObjectId('5cb0a55fe39a5cbeb4a206d7'),
#   'type': 'FeatureCollection',
#   'features': {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9602499, -37.81190077]},
#    'properties': {'FIELD1': 67,
#     'Census year': 2015,
#     'Block ID': 74,
#     'Property ID': 106018,
#     'Base property ID': 106018,
#     'Street address': '395-397 Little Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Horse Bazaar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 50}},
#   'dist': {'calculated': 68.10091452076718,
#    'location': [144.9602499, -37.81190077]}},
#  {'_id': ObjectId('5cbb067ae39a5cbeb4a82260'),
#   'type': 'FeatureCollection',
#   'features': {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9615331, -37.81234775]},
#    'properties': {'sensor_id': 56,
#     'sensor_description': 'Lonsdale St - Elizabeth St (North)',
#     'sensor_name': 'Lon364_T',
#     'installation_date': '25/07/2018',
#     'status': 'A',
#     'note': '',
#     'direction_1': 'East',
#     'direction_2': 'West'}},
#   'dist': {'calculated': 121.56627721390748,
#    'location': [144.9615331, -37.81234775]}}]
