# %%
import pandas as pd

# %%
data = pd.read_csv("pedestrian/January_2018.csv")

# %%
df = data.drop(columns=['Flagstaff Station', 'Flinders St-Swanston St (West)', 'Webb Bridge', 'Flinders St-Elizabeth St (East)', 'City Square'])

# %%
df = df.replace(-1, 0)
df.head(5)
# Out:
#          Date  Hour  State Library  Collins Place (South)  \
# 0  01/01/2018     0           1709                    812
# 1  01/01/2018     1           1511                    218
# 2  01/01/2018     2            666                     82
# 3  01/01/2018     3            301                     43
# 4  01/01/2018     4            181                     25
#
#    Collins Place (North)  Melbourne Central  Town Hall (West)  \
# 0                    326               2996              3052
# 1                    118               3481              3204
# 2                     64               1721              2042
# 3                     44               1056              1021
# 4                      9                417               523
#
#    Bourke Street Mall (North)  Bourke Street Mall (South)  \
# 0                         895                         734
# 1                         890                         590
# 2                         435                         317
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format='%d/%m/%Y')
df["Hour"] = pd.to_timedelta(df["Hour"], unit = 'h')
df["Date"] = df['Date'] + df['Hour']
df = df.drop(columns=['Hour'])
df = df.set_index(['Date'])

# %%
df.head(5)
# Out:
#                      State Library  Collins Place (South)  \
# Date
# 2018-01-01 00:00:00           1709                    812
# 2018-01-01 01:00:00           1511                    218
# 2018-01-01 02:00:00            666                     82
# 2018-01-01 03:00:00            301                     43
# 2018-01-01 04:00:00            181                     25
#
#                      Collins Place (North)  Melbourne Central  \
# Date
# 2018-01-01 00:00:00                    326               2996
# 2018-01-01 01:00:00                    118               3481
# 2018-01-01 02:00:00                     64               1721
# 2018-01-01 03:00:00                     44               1056
# 2018-01-01 04:00:00                      9                417
#
#                      Town Hall (West)  Bourke Street Mall (North)  \
# Date
# 2018-01-01 00:00:00              3052                         895
# 2018-01-01 01:00:00              3204                         890
# ...

# %%
df.iloc[:,0:1].to_csv('pedestrian_wrangled.csv')

# %%
df2 = pd.read_csv('pedestrian_wrangled.csv')

# %%
df2
# Out:
#                     Date  State Library
# 0    2018-01-01 00:00:00           1709
# 1    2018-01-01 01:00:00           1511
# 2    2018-01-01 02:00:00            666
# 3    2018-01-01 03:00:00            301
# 4    2018-01-01 04:00:00            181
# 5    2018-01-01 05:00:00             72
# 6    2018-01-01 06:00:00             46
# 7    2018-01-01 07:00:00             60
# 8    2018-01-01 08:00:00             90
# 9    2018-01-01 09:00:00            191
# 10   2018-01-01 10:00:00            300
# 11   2018-01-01 11:00:00            438
# 12   2018-01-01 12:00:00            719
# 13   2018-01-01 13:00:00            952
# 14   2018-01-01 14:00:00           1056
# 15   2018-01-01 15:00:00           1102
# 16   2018-01-01 16:00:00           1101
# 17   2018-01-01 17:00:00           1158
# 18   2018-01-01 18:00:00           1112
# 19   2018-01-01 19:00:00            904
# 20   2018-01-01 20:00:00            828
# 21   2018-01-01 21:00:00            646
# ...

# %% [markdown]
# ## Using firebase

# %%
import csv
import firebase_admin
import google.cloud
from firebase_admin import credentials, firestore

cred = credentials.Certificate("ServiceAccountKey.json")
app = firebase_admin.initialize_app(cred)

store = firestore.client()

# %%
file_path = "pedestrian_wrangled.csv"
collection_name = "state_library"

# %%
def batch_data(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]


data = []
headers = []
with open(file_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            for header in row:
                headers.append(header)
            line_count += 1
        else:
            obj = {}
            for idx, item in enumerate(row):
                obj[headers[idx]] = item
            data.append(obj)
            line_count += 1
    print(f'Processed {line_count} lines.')

for batched_data in batch_data(data, 499):
    batch = store.batch()
    for data_item in batched_data:
        doc_ref = store.collection(collection_name).document()
        batch.set(doc_ref, data_item)
    batch.commit()

print('Done')

# %%
with open('temp.json', 'w') as f:
    f.write(df2.to_json(orient='records', lines=True))

# %% [markdown]
# ## Using pyrebase

# %%
import pyrebase

config = {
  "apiKey": "AIzaSyAYMI2sjacA60um3pSLrqTD-aYXfZJhVaA",
  "authDomain": "visualisation-6ea20.firebaseapp.com",
  "databaseURL": "https://visualisation-6ea20.firebaseio.com",
  "storageBucket": "visualisation-6ea20.appspot.com",
  "serviceAccount": "ServiceAccountKey.json",
  "projectId" : "visualisation-6ea20"
}

firebase = pyrebase.initialize_app(config)

# %%
db = firebase.database()
db.child("users").child("Morty")

# %%
j = df2.to_json(orient='records')

# %%
db.child("users").push(j)

# %%
j

# %%
users = db.child("users").get()
print(users.val()) # {"Morty": {"name": "Mortimer 'Morty' Smith"}, "Rick": {"name": "Rick Sanchez"}}

# %%
js = df.to_json(orient='columns')

# %%
f = open("myfile.json", "w")
f.write(js)
f.close()

# %%
import datetime

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# Use a service account
cred = credentials.Certificate('ServiceAccountKey.json')
firebase_admin.initialize_app(cred)

db = firestore.client()

# %%
data = {
    u'stringExample': u'Hello, World!',
    u'booleanExample': True,
    u'numberExample': 3.14159265,
    u'dateExample': datetime.datetime.now(),
    u'arrayExample': [5, True, u'hello'],
    u'nullExample': None,
    u'objectExample': {
        u'a': 5,
        u'b': True
    }
}

db.collection(u'data').document(u'two').set(data)
# Out:
# update_time {
#   seconds: 1554005305
#   nanos: 230986000
# }

# %% [markdown]
# ## Upload data

# %%
# For all item in df 1 , upload it to databse

for i in range (df2.shape[0]):
    data = {    
        u'date': pd.to_datetime(df2['Date'][i]),
        u'location' : df2.columns[1],
        u'count': int(df2[df2.columns[1]][i])
    }

    db.collection(u'data').document().set(data)

# %% [markdown]
# ## Get one document

# %%
doc_ref = db.collection(u'data').document(u'test1')

try:
    doc = doc_ref.get()
    print(u'Document data: {}'.format(doc.to_dict()))
except google.cloud.exceptions.NotFound:
    print(u'No such document!')
# Out:
# Document data: {'location': 'State Library', 'numberExample': 1709, 'date': DatetimeWithNanoseconds(2018, 1, 1, 1, 0, tzinfo=<UTC>)}

# %% [markdown]
# ## Get all

# %%
docs = db.collection(u'data').get()

for doc in docs:
    print(u'{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# 03u91wtFBTpdFlwNJg1i => {'count': 256, 'date': DatetimeWithNanoseconds(2018, 1, 30, 23, 0, tzinfo=<UTC>), 'location': 'State Library'}
# 0496I3RKSHRpYQyXBoF1 => {'count': 637, 'date': DatetimeWithNanoseconds(2018, 1, 17, 22, 0, tzinfo=<UTC>), 'location': 'State Library'}
# 0TkvzajDJc4lWNEoiMIm => {'date': DatetimeWithNanoseconds(2018, 1, 26, 0, 0, tzinfo=<UTC>), 'location': 'State Library', 'count': 283}
# 0zTtxdYWHQ9C2inmQkko => {'count': 97, 'date': DatetimeWithNanoseconds(2018, 1, 8, 0, 0, tzinfo=<UTC>), 'location': 'State Library'}
# 12NZrZyxrjUP6rYRMwLb => {'count': 122, 'date': DatetimeWithNanoseconds(2018, 1, 29, 23, 0, tzinfo=<UTC>), 'location': 'State Library'}
# 12qYyywUbd6ndbETVELA => {'date': DatetimeWithNanoseconds(2018, 1, 30, 1, 0, tzinfo=<UTC>), 'location': 'State Library', 'count': 26}
# 1IiTi9MgH6fPOrGfOmvk => {'count': 755, 'date': DatetimeWithNanoseconds(2018, 1, 31, 9, 0, tzinfo=<UTC>), 'location': 'State Library'}
# ...

# %% [markdown]
# ## Match Lat Lon

# %%
df = pd.read_csv('pedestrian_feb.csv')
df2 = pd.read_csv('Pedestrian_Counting_System_-_Sensor_Locations.csv')

# %%
df.head(1)
# Out:
#           date_time     day  hourly_counts       id  mdate     month  \
# 0  17/02/2019 19:00  Sunday           1361  2566102     17  February
#
#    sensor_id                 sensor_name  time  year  latitude  longitude
# 0          1  Bourke Street Mall (North)    19  2019       NaN        NaN

# %%
df2[columns=['latitude','longitude']]
# Out:
#   File "<ipython-input-9-4b020e3e5db8>", line 1
#     df2[columns=['latitude','longitude']]
#                ^
# SyntaxError: invalid syntax
