# %% [markdown]
# ## Import Libraries

# %%
from pymongo import MongoClient
from bson.son import SON
import json

# %%
import pprint

# %%
MONGODB_HOST = 'localhost'
MONGODB_PORT = 27017
DBS_NAME = 'mydb'
COLLECTION_NAME = 'projects'
FIELDS = "FeatureCollection"

# %%
client = MongoClient()
db = client.mydb
collection = db.projects

# %% [markdown]
# ### Code

# %%
def dashboard_projects():
    connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
    collection = connection[DBS_NAME][COLLECTION_NAME]
    projects = collection.find_one({"type": "FeatureCollection"}, {"_id":0})

    return projects

# %%
dashboard_projects()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.965463853978, -37.8077644149636]},
#    'properties': {'FIELD1': 0,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Old Melbourne Gaol Crime & Justice Experience'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.953478052064, -37.8242574266145]},
#    'properties': {'FIELD1': 1,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Polly Woodside'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.967252924593, -37.8266045432686]},
#    'properties': {'FIELD1': 2,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Australian Centre for Contemporary Art'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.968837288153, -37.8219947335768]},
#    'properties': {'FIELD1': 3,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Victorian Arts Centre'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.969899048343, -37.8174831423197]},
#    'properties': {'FIELD1': 4,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Ian Potter Centre: NGV Australia'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.9839700954, -37.8188662730911]},
#    'properties': {'FIELD1': 5,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Thoroughbred Racing Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.948496661709, -37.8213744301481]},
#    'properties': {'FIELD1': 6,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Fox Classic Car Collection'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.971690718887, -37.8035518129299]},
#    'properties': {'FIELD1': 7,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Melbourne Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.984669809381, -37.8189544909462]},
#    'properties': {'FIELD1': 8,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'National Sports Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.980554992725, -37.8145407488014]},
#    'properties': {'FIELD1': 9,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': "Sinclair's Cottage"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.954039975197, -37.8222182774409]},
#    'properties': {'FIELD1': 10,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Victoria Police Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.960426777129, -37.8191798798062]},
#    'properties': {'FIELD1': 11,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Immigration Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.975373745366, -37.8085761281612]},
#    'properties': {'FIELD1': 12,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Fire Services Museum Victoria'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.964156669702, -37.7973939595503]},
#    'properties': {'FIELD1': 13,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Ian Potter Museum Of Art'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.954027907736, -37.8133854259085]},
#    'properties': {'FIELD1': 14,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Koorie Heritage Trust Inc'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.979471339826, -37.8144604899837]},
#    'properties': {'FIELD1': 15,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': "Cooks' Cottage"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.971521914952, -37.80460262432]},
#    'properties': {'FIELD1': 16,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Royal Exhibition Building'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.969070431323, -37.8176107327202]},
#    'properties': {'FIELD1': 17,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'Australian Centre For The Moving Image (ACMI)'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96923385414, -37.8107686127655]},
#    'properties': {'FIELD1': 18,
#     'Theme': 'Place Of Assembly',
#     'Sub Theme': 'Art Gallery/Museum',
#     'Feature Name': 'The Museum Of Australian Chinese History'}}]}

# %%
# Call all documents
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
projects2 = collection.find_one({"type": "FeatureCollection"}, {"_id":0})

# %%
db = MongoClient()
latitude = -37.44609999
longitude = 144.96923385414
max_distance = 1000 #meters

# %%
location = [144.965234, -37.8076]

# %%
db.collection.drop_indexes()

# %%
for idx in db.collection.list_indexes():
    print (idx)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_'), ('ns', 'mydb.collection')])
# SON([('v', 2), ('key', SON([('features.geometry.coordinates', '2dsphere')])), ('name', 'features.geometry.coordinates_2dsphere'), ('ns', 'mydb.collection'), ('2dsphereIndexVersion', 3)])

# %%
db.collection.create_index([( "features.geometry.coordinates", "2dsphere" )])
# Out:
# 'features.geometry.coordinates_2dsphere'

# %%
## Unwind search

pipeline = [{"$unwind": "$features"},
            {"$match":{'features.geometry.coordinates':[144.965463853978, -37.8077644149636]}},
            {"$group": {"_id": "$features"}}]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# []

# %%
gallery = [{"$unwind": "$features"},
            {"$match":{'features.properties.Sub Theme' : 'Art Gallery/Museum'}},
            {"$group": {"_id": "$features"}}]

pprint.pprint(list(collection.aggregate(gallery)))
# Out:
# [{'_id': {'geometry': {'coordinates': [144.969070431323, -37.8176107327202],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 17,
#                          'Feature Name': 'Australian Centre For The Moving '
#                                          'Image (ACMI)',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.971521914952, -37.80460262432],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 16,
#                          'Feature Name': 'Royal Exhibition Building',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.979471339826, -37.8144604899837],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 15,
#                          'Feature Name': "Cooks' Cottage",
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.975373745366, -37.8085761281612],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 12,
#                          'Feature Name': 'Fire Services Museum Victoria',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.960426777129, -37.8191798798062],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 11,
#                          'Feature Name': 'Immigration Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.980554992725, -37.8145407488014],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 9,
#                          'Feature Name': "Sinclair's Cottage",
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.954027907736, -37.8133854259085],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 14,
#                          'Feature Name': 'Koorie Heritage Trust Inc',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.984669809381, -37.8189544909462],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 8,
#                          'Feature Name': 'National Sports Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.9839700954, -37.8188662730911],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 5,
#                          'Feature Name': 'Thoroughbred Racing Gallery',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.967252924593, -37.8266045432686],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 2,
#                          'Feature Name': 'Australian Centre for Contemporary '
#                                          'Art',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.968837288153, -37.8219947335768],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 3,
#                          'Feature Name': 'Victorian Arts Centre',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.953478052064, -37.8242574266145],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 1,
#                          'Feature Name': 'Polly Woodside',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.948496661709, -37.8213744301481],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 6,
#                          'Feature Name': 'Fox Classic Car Collection',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.964156669702, -37.7973939595503],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 13,
#                          'Feature Name': 'The Ian Potter Museum Of Art',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.969899048343, -37.8174831423197],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 4,
#                          'Feature Name': 'The Ian Potter Centre: NGV Australia',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.971690718887, -37.8035518129299],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 7,
#                          'Feature Name': 'Melbourne Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.954039975197, -37.8222182774409],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 10,
#                          'Feature Name': 'Victoria Police Museum',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.96923385414, -37.8107686127655],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 18,
#                          'Feature Name': 'The Museum Of Australian Chinese '
#                                          'History',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}},
#  {'_id': {'geometry': {'coordinates': [144.965463853978, -37.8077644149636],
#                        'type': 'Point'},
#           'properties': {'FIELD1': 0,
#                          'Feature Name': 'Old Melbourne Gaol Crime & Justice '
#                                          'Experience',
#                          'Sub Theme': 'Art Gallery/Museum',
#                          'Theme': 'Place Of Assembly'},
#           'type': 'Feature'}}]

# %% [markdown]
# ## Working code

# %%
pipeline = [
        {'$geoNear': {
            'near' : { 'type' : "Point", 'coordinates' : location },
             'distanceField': "dist.calculated",
             'maxDistance': 100,
             'includeLocs': "dist.location",
              'key': 'features.geometry.coordinates',
             'uniqueDocs': False,
             'spherical': True}},
    { "$unwind" : "$features" },
    { "$redact" : {   
        "$cond" : {
            "if" : { "$eq" : [ { "$cmp" : [ "$features.geometry.coordinates", "$dist.location" ] }, 0 ] },
            "then" : "$$KEEP",
            "else" : "$$PRUNE"
        }
    }
}
]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('5ca63a65122b9a6192720138'),
#   'dist': {'calculated': 27.27001406965783,
#            'location': [144.965463853978, -37.8077644149636]},
#   'features': {'geometry': {'coordinates': [144.965463853978,
#                                             -37.8077644149636],
#                             'type': 'Point'},
#                'properties': {'FIELD1': 0,
#                               'Feature Name': 'Old Melbourne Gaol Crime & '
#                                               'Justice Experience',
#                               'Sub Theme': 'Art Gallery/Museum',
#                               'Theme': 'Place Of Assembly'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5ccd860ce39a5cbeb4b1bc58'),
#   'dist': {'calculated': 88.52102010398153,
#            'location': [144.9645504, -37.80818365]},
#   'features': {'geometry': {'coordinates': [144.9645504, -37.80818365],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 76,
#                               'Street address': '124 La Trobe Street',
#                               'Trading name': "Pearson and Murph'y Cafe"},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5ccd860ce39a5cbeb4b1bc58'),
#   'dist': {'calculated': 88.52102010398153,
#            'location': [144.9645504, -37.80818365]},
#   'features': {'geometry': {'coordinates': [144.9645504, -37.80818365],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 80,
#                               'Street address': '124 La Trobe Street',
#                               'Trading name': "Pearson and Murph'y Cafe"},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %% [markdown]
# ### Check

# %%
a1 = [144.9654, -37.8076]
a2 = [144.9656988, -37.80619915]

distance_finder(a1, a2)
# Out:
# 157.69509130741474 m

# %% [markdown]
# ## Implement Automation

# %%
click = [144.96402401414252, -37.8133816331916]
click = [ round(elem, 14) for elem in click ]
click
# Out:
# [144.96402401414252, -37.8133816331916]

# %%
location = [144.965234, -37.8076]

# %%
pipeline = [
        {'$geoNear': {
            'near' : { 'type' : "Point", 'coordinates' : click },
             'distanceField': "dist.calculated",
             'maxDistance': 500,
             'includeLocs': "dist.location",
              'key': 'features.geometry.coordinates',
             'uniqueDocs': False,
             'spherical': True}},
    { "$unwind" : "$features" },
    { "$redact" : {   
        "$cond" : {
            "if" : { "$eq" : [ { "$cmp" : [ "$features.geometry.coordinates", "$dist.location" ] }, 0 ] },
            "then" : "$$KEEP",
            "else" : "$$PRUNE"
        }
    }
}
]

pprint.pprint(list(collection.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 18.504773621888866,
#            'location': [144.9638295, -37.81344503]},
#   'features': {'geometry': {'coordinates': [144.9638295, -37.81344503],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 54,
#                               'Street address': '314-336 Bourke Street',
#                               'Trading name': 'The Salon By Louis Roderer',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 18.504773621888866,
#            'location': [144.9638295, -37.81344503]},
#   'features': {'geometry': {'coordinates': [144.9638295, -37.81344503],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 99,
#                               'Street address': '314-336 Bourke Street',
#                               'Trading name': 'Brunetti Myer Melbourne',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5cbb067ae39a5cbeb4a82260'),
#   'dist': {'calculated': 100.09442310180268,
#            'location': [144.9651532, -37.8134944]},
#   'features': {'geometry': {'coordinates': [144.9651532, -37.8134944],
#                             'type': 'Point'},
#                'properties': {'direction_1': 'West',
#                               'direction_2': 'East',
#                               'installation_date': '24/03/2009',
#                               'note': '',
#                               'sensor_description': 'Bourke Street Mall '
#                                                     '(North)',
#                               'sensor_id': 1,
#                               'sensor_name': 'Bou292_T',
#                               'status': 'A'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %%
connection = MongoClient(MONGODB_HOST, MONGODB_PORT)
collection = connection[DBS_NAME][COLLECTION_NAME]
pprint.pprint(list(collection.aggregate(pipeline)))
connection.close()
# Out:
# [{'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 18.504773621888866,
#            'location': [144.9638295, -37.81344503]},
#   'features': {'geometry': {'coordinates': [144.9638295, -37.81344503],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 54,
#                               'Street address': '314-336 Bourke Street',
#                               'Trading name': 'The Salon By Louis Roderer',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 18.504773621888866,
#            'location': [144.9638295, -37.81344503]},
#   'features': {'geometry': {'coordinates': [144.9638295, -37.81344503],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 99,
#                               'Street address': '314-336 Bourke Street',
#                               'Trading name': 'Brunetti Myer Melbourne',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5cbb067ae39a5cbeb4a82260'),
#   'dist': {'calculated': 100.09442310180268,
#            'location': [144.9651532, -37.8134944]},
#   'features': {'geometry': {'coordinates': [144.9651532, -37.8134944],
#                             'type': 'Point'},
#                'properties': {'direction_1': 'West',
#                               'direction_2': 'East',
#                               'installation_date': '24/03/2009',
#                               'note': '',
#                               'sensor_description': 'Bourke Street Mall '
#                                                     '(North)',
#                               'sensor_id': 1,
#                               'sensor_name': 'Bou292_T',
#                               'status': 'A'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %% [markdown]
# ## Calling Cafe

# %%
click = [144.96518348629792, -37.81309237049503]

# %%
import pandas as pd

# %%
pipeline_cafe = [
        {'$geoNear': {
            'near' : { 'type' : "Point", 'coordinates' : click },
             'distanceField': "dist.calculated",
             'maxDistance': 3000,
             'includeLocs': "dist.location",
              'key': 'features.geometry.coordinates',
             'uniqueDocs': False,
             'spherical': True}},
    {"$match" : {"features.properties.Type":"Cafe"}},
    { "$unwind" : "$features" },
    { "$redact" : {   
        "$cond" : {
            "if" : { "$eq" : [ { "$cmp" : [ "$features.geometry.coordinates", "$dist.location" ] }, 0 ]},
            "then" : "$$KEEP",
            "else" : "$$PRUNE"
            }
        }
    }
]

pprint.pprint(list(collection.aggregate(pipeline_cafe)))
# Out:
# [{'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 16.197999502475984,
#            'location': [144.9649993, -37.81309229]},
#   'features': {'geometry': {'coordinates': [144.9649993, -37.81309229],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 42,
#                               'Street address': '191-205 Swanston Street',
#                               'Trading name': 'Soul Cafe',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'},
#  {'_id': ObjectId('5ccd8bcce39a5cbeb4b1c0f2'),
#   'dist': {'calculated': 16.197999502475984,
#            'location': [144.9649993, -37.81309229]},
#   'features': {'geometry': {'coordinates': [144.9649993, -37.81309229],
#                             'type': 'Point'},
#                'properties': {'Number of seats': 30,
#                               'Street address': '191-205 Swanston Street',
#                               'Trading name': 'Soul Cafe',
#                               'Type': 'Cafe'},
#                'type': 'Feature'},
#   'type': 'FeatureCollection'}]

# %%
a = collection.find(
   {
     "features.geometry.coordinates":
       { "$near" :
          {
            "$geometry": { 'type': "Point", "coordinates" : click },
            "$maxDistance": 1/111.12
          }
       },
        "features.properties.Type":"Cafe"
   }
)


for i in a:
    print(i)

# %%
collection.find_one({"type": "FeatureCollection"}, {"_id":0})
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.962209, -37.80045792]},
#    'properties': {'FIELD1': 0,
#     'Census year': 2015,
#     'Block ID': 242,
#     'Property ID': 104461,
#     'Base property ID': 104461,
#     'Street address': '191-197 Grattan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Prince Alfred Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.962209, -37.80045792]},
#    'properties': {'FIELD1': 1,
#     'Census year': 2015,
#     'Block ID': 242,
#     'Property ID': 104461,
#     'Base property ID': 104461,
#     'Street address': '191-197 Grattan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Prince Alfred Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.960916, -37.80243195]},
#    'properties': {'FIELD1': 2,
#     'Census year': 2015,
#     'Block ID': 257,
#     'Property ID': 105516,
#     'Base property ID': 105516,
#     'Street address': '154-160 Leicester Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'The Corkman Irish Pub',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 150}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.960916, -37.80243195]},
#    'properties': {'FIELD1': 3,
#     'Census year': 2015,
#     'Block ID': 257,
#     'Property ID': 105516,
#     'Base property ID': 105516,
#     'Street address': '154-160 Leicester Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'The Corkman Irish Pub',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9656988, -37.80619915]},
#    'properties': {'FIELD1': 4,
#     'Census year': 2015,
#     'Block ID': 266,
#     'Property ID': 106081,
#     'Base property ID': 106081,
#     'Street address': '27-31 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'John Curtin Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 71}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9656988, -37.80619915]},
#    'properties': {'FIELD1': 5,
#     'Census year': 2015,
#     'Block ID': 266,
#     'Property ID': 106081,
#     'Base property ID': 106081,
#     'Street address': '27-31 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'John Curtin Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9704262, -37.79652005]},
#    'properties': {'FIELD1': 6,
#     'Census year': 2015,
#     'Block ID': 215,
#     'Property ID': 108202,
#     'Base property ID': 108202,
#     'Street address': '415-421 Rathdowne Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'The Beaufort',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9673764, -37.79998572]},
#    'properties': {'FIELD1': 7,
#     'Census year': 2015,
#     'Block ID': 218,
#     'Property ID': 106215,
#     'Base property ID': 106215,
#     'Street address': '298 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Carlton Yacht Club Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9665747, -37.80530329]},
#    'properties': {'FIELD1': 8,
#     'Census year': 2015,
#     'Block ID': 267,
#     'Property ID': 106251,
#     'Base property ID': 106251,
#     'Street address': '66-88 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Lagers On Lygon',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9672432, -37.8005263]},
#    'properties': {'FIELD1': 9,
#     'Census year': 2015,
#     'Block ID': 218,
#     'Property ID': 106222,
#     'Base property ID': 106222,
#     'Street address': '270-276 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'University Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9672432, -37.8005263]},
#    'properties': {'FIELD1': 10,
#     'Census year': 2015,
#     'Block ID': 218,
#     'Property ID': 106222,
#     'Base property ID': 106222,
#     'Street address': '270-276 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'University Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 58}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9629068, -37.80475348]},
#    'properties': {'FIELD1': 11,
#     'Census year': 2015,
#     'Block ID': 264,
#     'Property ID': 109322,
#     'Base property ID': 109322,
#     'Street address': '593-597 Swanston Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Queensberry Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9657541, -37.79725532]},
#    'properties': {'FIELD1': 12,
#     'Census year': 2015,
#     'Block ID': 204,
#     'Property ID': 101613,
#     'Base property ID': 101613,
#     'Street address': '377-391 Cardigan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Clyde Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 70}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9657541, -37.79725532]},
#    'properties': {'FIELD1': 13,
#     'Census year': 2015,
#     'Block ID': 204,
#     'Property ID': 101613,
#     'Base property ID': 101613,
#     'Street address': '377-391 Cardigan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Clyde Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9645057, -37.80448528]},
#    'properties': {'FIELD1': 14,
#     'Census year': 2015,
#     'Block ID': 255,
#     'Property ID': 101593,
#     'Base property ID': 101593,
#     'Street address': '91-95 Cardigan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Hotel Lincoln',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 62}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9645057, -37.80448528]},
#    'properties': {'FIELD1': 15,
#     'Census year': 2015,
#     'Block ID': 255,
#     'Property ID': 101593,
#     'Base property ID': 101593,
#     'Street address': '91-95 Cardigan Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Hotel Lincoln',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 20}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9678126, -37.79694555]},
#    'properties': {'FIELD1': 16,
#     'Census year': 2015,
#     'Block ID': 214,
#     'Property ID': 106186,
#     'Base property ID': 106186,
#     'Street address': '414-422 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Astor Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9670522, -37.80245924]},
#    'properties': {'FIELD1': 17,
#     'Census year': 2015,
#     'Block ID': 247,
#     'Property ID': 106238,
#     'Base property ID': 106238,
#     'Street address': '192-202 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Players On Lygon',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 20}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9667699, -37.80344164]},
#    'properties': {'FIELD1': 18,
#     'Census year': 2015,
#     'Block ID': 252,
#     'Property ID': 106244,
#     'Base property ID': 106244,
#     'Street address': '160-162 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Bar Centrale',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 73}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9667699, -37.80344164]},
#    'properties': {'FIELD1': 19,
#     'Census year': 2015,
#     'Block ID': 252,
#     'Property ID': 106244,
#     'Base property ID': 106244,
#     'Street address': '160-162 Lygon Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'Bar Centrale',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9589387, -37.80389369]},
#    'properties': {'FIELD1': 20,
#     'Census year': 2015,
#     'Block ID': 260,
#     'Property ID': 103276,
#     'Base property ID': 103276,
#     'Street address': '614-616 Elizabeth Street',
#     'CLUE small area': 'Carlton',
#     'Trading name': 'The Last Jar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 90}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9705847, -37.81393777]},
#    'properties': {'FIELD1': 21,
#     'Census year': 2015,
#     'Block ID': 37,
#     'Property ID': 102158,
#     'Base property ID': 102158,
#     'Street address': '86-88 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Collins Quarter ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 171}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9705847, -37.81393777]},
#    'properties': {'FIELD1': 22,
#     'Census year': 2015,
#     'Block ID': 37,
#     'Property ID': 102158,
#     'Base property ID': 102158,
#     'Street address': '86-88 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Collins Quarter ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 90}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9694031, -37.81175137]},
#    'properties': {'FIELD1': 23,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 106433,
#     'Base property ID': 106433,
#     'Street address': '18-24 Market Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Ding Dong Lounge',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9692645, -37.81207094]},
#    'properties': {'FIELD1': 24,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 101217,
#     'Base property ID': 101217,
#     'Street address': '124-128 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Welcome Stranger',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9700684, -37.81165123]},
#    'properties': {'FIELD1': 25,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 103599,
#     'Base property ID': 103599,
#     'Street address': '169-171 Exhibition Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': '1806',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 107}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9705132, -37.81567009]},
#    'properties': {'FIELD1': 26,
#     'Census year': 2015,
#     'Block ID': 17,
#     'Property ID': 103925,
#     'Base property ID': 103925,
#     'Street address': '121-123 Flinders Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Fashion Lounge',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 100}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9671591, -37.81011116]},
#    'properties': {'FIELD1': 27,
#     'Census year': 2015,
#     'Block ID': 77,
#     'Property ID': 108573,
#     'Base property ID': 108573,
#     'Street address': '270 Russell Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Whisky and Alement',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 45}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9702485, -37.81191058]},
#    'properties': {'FIELD1': 28,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 101221,
#     'Base property ID': 101221,
#     'Street address': '94-96 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Elephant and Wheelbarrow',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 240}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9702485, -37.81191058]},
#    'properties': {'FIELD1': 29,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 101221,
#     'Base property ID': 101221,
#     'Street address': '94-96 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Elephant and Wheelbarrow',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 36}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9716757, -37.81587662]},
#    'properties': {'FIELD1': 30,
#     'Census year': 2015,
#     'Block ID': 17,
#     'Property ID': 574438,
#     'Base property ID': 574438,
#     'Street address': '84-94 Flinders Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Eau-De-Vie ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 136}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9723505, -37.81207814]},
#    'properties': {'FIELD1': 31,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 106559,
#     'Base property ID': 106559,
#     'Street address': '20 Meyers Place',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Meyers Place Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 63}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9687387, -37.81235798]},
#    'properties': {'FIELD1': 32,
#     'Census year': 2015,
#     'Block ID': 57,
#     'Property ID': 101214,
#     'Base property ID': 101214,
#     'Street address': '146-150 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'FM Karaoke Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 15}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9700863, -37.81640747]},
#    'properties': {'FIELD1': 33,
#     'Census year': 2015,
#     'Block ID': 17,
#     'Property ID': 104021,
#     'Base property ID': 104021,
#     'Street address': '142-148 Flinders Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Duke',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9713489, -37.8143446]},
#    'properties': {'FIELD1': 34,
#     'Census year': 2015,
#     'Block ID': 27,
#     'Property ID': 102064,
#     'Base property ID': 102064,
#     'Street address': '69-73 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'La Chinesca',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 110}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.96859, -37.8091536]},
#    'properties': {'FIELD1': 35,
#     'Census year': 2015,
#     'Block ID': 87,
#     'Property ID': 106057,
#     'Base property ID': 106057,
#     'Street address': '106 Little Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Troika Bar ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.96859, -37.8091536]},
#    'properties': {'FIELD1': 36,
#     'Census year': 2015,
#     'Block ID': 87,
#     'Property ID': 106057,
#     'Base property ID': 106057,
#     'Street address': '106 Little Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Troika Bar ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9724291, -37.8109513]},
#    'properties': {'FIELD1': 37,
#     'Census year': 2015,
#     'Block ID': 58,
#     'Property ID': 108986,
#     'Base property ID': 108986,
#     'Street address': '161 Spring Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Singlo Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9705847, -37.81393777]},
#    'properties': {'FIELD1': 38,
#     'Census year': 2015,
#     'Block ID': 37,
#     'Property ID': 102158,
#     'Base property ID': 102158,
#     'Street address': '86-88 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Ra',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9581156, -37.80861319]},
#    'properties': {'FIELD1': 39,
#     'Census year': 2015,
#     'Block ID': 114,
#     'Property ID': 104090,
#     'Base property ID': 104090,
#     'Street address': '422-428 Queen Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': "Muleta's",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 100}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9581156, -37.80861319]},
#    'properties': {'FIELD1': 40,
#     'Census year': 2015,
#     'Block ID': 114,
#     'Property ID': 104090,
#     'Base property ID': 104090,
#     'Street address': '422-428 Queen Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': "Muleta's",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9715659, -37.81212537]},
#    'properties': {'FIELD1': 41,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 101113,
#     'Base property ID': 101113,
#     'Street address': '59-63 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Madam Brussels ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9715659, -37.81212537]},
#    'properties': {'FIELD1': 42,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 101113,
#     'Base property ID': 101113,
#     'Street address': '59-63 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Madam Brussels ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 100}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9708344, -37.81560645]},
#    'properties': {'FIELD1': 43,
#     'Census year': 2015,
#     'Block ID': 17,
#     'Property ID': 103924,
#     'Base property ID': 103924,
#     'Street address': '107-109 Flinders Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Bambu Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9700863, -37.81640747]},
#    'properties': {'FIELD1': 44,
#     'Census year': 2015,
#     'Block ID': 17,
#     'Property ID': 104021,
#     'Base property ID': 104021,
#     'Street address': '142-148 Flinders Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Duke',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 240}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9698467, -37.81516811]},
#    'properties': {'FIELD1': 45,
#     'Census year': 2015,
#     'Block ID': 27,
#     'Property ID': 597183,
#     'Base property ID': 102071,
#     'Street address': '121-131 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Spice Market',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 140}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.967558, -37.80889245]},
#    'properties': {'FIELD1': 46,
#     'Census year': 2015,
#     'Block ID': 87,
#     'Property ID': 101023,
#     'Base property ID': 101023,
#     'Street address': '25 Bennetts Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Bennetts Lane Jazz Club',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 250}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.966904, -37.80951668]},
#    'properties': {'FIELD1': 47,
#     'Census year': 2015,
#     'Block ID': 87,
#     'Property ID': 108567,
#     'Base property ID': 108567,
#     'Street address': '300 Russell Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Jankara Japanese Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.972676, -37.8112003]},
#    'properties': {'FIELD1': 48,
#     'Census year': 2015,
#     'Block ID': 58,
#     'Property ID': 101238,
#     'Base property ID': 101238,
#     'Street address': '2-8 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Imperial Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 200}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.972676, -37.8112003]},
#    'properties': {'FIELD1': 49,
#     'Census year': 2015,
#     'Block ID': 58,
#     'Property ID': 101238,
#     'Base property ID': 101238,
#     'Street address': '2-8 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Imperial Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 68}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9719903, -37.81074304]},
#    'properties': {'FIELD1': 50,
#     'Census year': 2015,
#     'Block ID': 58,
#     'Property ID': 105828,
#     'Base property ID': 105828,
#     'Street address': '19-25 Little Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': "Mrs Parma's ",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9720472, -37.81193572]},
#    'properties': {'FIELD1': 51,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 101109,
#     'Base property ID': 101109,
#     'Street address': '39-43 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Spleen Central',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 100}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9715659, -37.81212537]},
#    'properties': {'FIELD1': 52,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 101113,
#     'Base property ID': 101113,
#     'Street address': '59-63 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Club Asuka',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9711999, -37.81285806]},
#    'properties': {'FIELD1': 53,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 103626,
#     'Base property ID': 103626,
#     'Street address': '114-122 Exhibition Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'European Bier Cafe',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 250}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9724927, -37.81278444]},
#    'properties': {'FIELD1': 54,
#     'Census year': 2015,
#     'Block ID': 38,
#     'Property ID': 105911,
#     'Base property ID': 105911,
#     'Street address': '37 Little Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Bar Lourinha',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9723932, -37.81279876]},
#    'properties': {'FIELD1': 55,
#     'Census year': 2015,
#     'Block ID': 38,
#     'Property ID': 105912,
#     'Base property ID': 105912,
#     'Street address': '39-41 Little Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Lupino',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699756, -37.80941489]},
#    'properties': {'FIELD1': 56,
#     'Census year': 2015,
#     'Block ID': 78,
#     'Property ID': 103618,
#     'Base property ID': 103618,
#     'Street address': '242-284 Exhibition Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Coopers Inn',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 300}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699756, -37.80941489]},
#    'properties': {'FIELD1': 57,
#     'Census year': 2015,
#     'Block ID': 78,
#     'Property ID': 103618,
#     'Base property ID': 103618,
#     'Street address': '242-284 Exhibition Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Coopers Inn',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9616126, -37.80752292]},
#    'properties': {'FIELD1': 58,
#     'Census year': 2015,
#     'Block ID': 115,
#     'Property ID': 104103,
#     'Base property ID': 104103,
#     'Street address': '34-38 Franklin Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Captain Melville ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 160}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9616126, -37.80752292]},
#    'properties': {'FIELD1': 59,
#     'Census year': 2015,
#     'Block ID': 115,
#     'Property ID': 104103,
#     'Base property ID': 104103,
#     'Street address': '34-38 Franklin Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Captain Melville ',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 70}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9721078, -37.8121518]},
#    'properties': {'FIELD1': 60,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 503031,
#     'Base property ID': 503031,
#     'Street address': '19-23 Meyers Place',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Loop Project Space & Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9721078, -37.8121518]},
#    'properties': {'FIELD1': 61,
#     'Census year': 2015,
#     'Block ID': 48,
#     'Property ID': 503031,
#     'Base property ID': 503031,
#     'Street address': '19-23 Meyers Place',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Loop Project Space & Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 148}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9605226, -37.80918797]},
#    'properties': {'FIELD1': 62,
#     'Census year': 2015,
#     'Block ID': 104,
#     'Property ID': 103219,
#     'Base property ID': 103219,
#     'Street address': '413-417 Elizabeth Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Workshop',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9605226, -37.80918797]},
#    'properties': {'FIELD1': 63,
#     'Census year': 2015,
#     'Block ID': 104,
#     'Property ID': 103219,
#     'Base property ID': 103219,
#     'Street address': '413-417 Elizabeth Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Workshop',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9626932, -37.80826292]},
#    'properties': {'FIELD1': 64,
#     'Census year': 2015,
#     'Block ID': 105,
#     'Property ID': 109318,
#     'Base property ID': 109318,
#     'Street address': '427-457 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Oxford Scholar Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 140}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9626932, -37.80826292]},
#    'properties': {'FIELD1': 65,
#     'Census year': 2015,
#     'Block ID': 105,
#     'Property ID': 109318,
#     'Base property ID': 109318,
#     'Street address': '427-457 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Oxford Scholar Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 56}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9583711, -37.80792152]},
#    'properties': {'FIELD1': 66,
#     'Census year': 2015,
#     'Block ID': 114,
#     'Property ID': 109493,
#     'Base property ID': 109493,
#     'Street address': '143-151 Therry Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Mercant Cross Hotel / Fancy Hanks Bar-B-Que',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 230}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9602499, -37.81190077]},
#    'properties': {'FIELD1': 67,
#     'Census year': 2015,
#     'Block ID': 74,
#     'Property ID': 106018,
#     'Base property ID': 106018,
#     'Street address': '395-397 Little Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Horse Bazaar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.967023, -37.817356]},
#    'properties': {'FIELD1': 68,
#     'Census year': 2015,
#     'Block ID': 15,
#     'Property ID': 109257,
#     'Base property ID': 109257,
#     'Street address': '1-7 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Young & Jacksons',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 120}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9676452, -37.81320485]},
#    'properties': {'FIELD1': 69,
#     'Census year': 2015,
#     'Block ID': 46,
#     'Property ID': 101130,
#     'Base property ID': 101130,
#     'Street address': '193-199 Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Carlton Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 140}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9645574, -37.81567229]},
#    'properties': {'FIELD1': 70,
#     'Census year': 2015,
#     'Block ID': 35,
#     'Property ID': 102141,
#     'Base property ID': 102141,
#     'Street address': '280-292 Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Charles Dickens Tavern',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 120}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9638507, -37.81763918]},
#    'properties': {'FIELD1': 71,
#     'Census year': 2015,
#     'Block ID': 14,
#     'Property ID': 103946,
#     'Base property ID': 103946,
#     'Street address': '313-315 Flinders Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Randy Dragon',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9631276, -37.81292437]},
#    'properties': {'FIELD1': 72,
#     'Census year': 2015,
#     'Block ID': 65,
#     'Property ID': 105875,
#     'Base property ID': 105875,
#     'Street address': '318-322 Little Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'NANT Whisky Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9631276, -37.81292437]},
#    'properties': {'FIELD1': 73,
#     'Census year': 2015,
#     'Block ID': 65,
#     'Property ID': 105875,
#     'Base property ID': 105875,
#     'Street address': '318-322 Little Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'NANT Whisky Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9643316, -37.81741878]},
#    'properties': {'FIELD1': 74,
#     'Census year': 2015,
#     'Block ID': 14,
#     'Property ID': 103172,
#     'Base property ID': 103172,
#     'Street address': '31-39 Elizabeth Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Joint Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 88}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9643316, -37.81741878]},
#    'properties': {'FIELD1': 75,
#     'Census year': 2015,
#     'Block ID': 14,
#     'Property ID': 103172,
#     'Base property ID': 103172,
#     'Street address': '31-39 Elizabeth Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'The Joint Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 46}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699175, -37.81784465]},
#    'properties': {'FIELD1': 76,
#     'Census year': 2015,
#     'Block ID': 6,
#     'Property ID': 578321,
#     'Base property ID': 573333,
#     'Street address': '2 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Beer De Luxe',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 200}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699175, -37.81784465]},
#    'properties': {'FIELD1': 77,
#     'Census year': 2015,
#     'Block ID': 6,
#     'Property ID': 578321,
#     'Base property ID': 573333,
#     'Street address': '2 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Beer De Luxe',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 400}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9667836, -37.81413595]},
#    'properties': {'FIELD1': 78,
#     'Census year': 2015,
#     'Block ID': 46,
#     'Property ID': 105962,
#     'Base property ID': 105962,
#     'Street address': '218-242 Little Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Little Sista',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 80}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9667836, -37.81413595]},
#    'properties': {'FIELD1': 79,
#     'Census year': 2015,
#     'Block ID': 46,
#     'Property ID': 105962,
#     'Base property ID': 105962,
#     'Street address': '218-242 Little Collins Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Little Sista',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 48}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9631276, -37.81292437]},
#    'properties': {'FIELD1': 80,
#     'Census year': 2015,
#     'Block ID': 65,
#     'Property ID': 105875,
#     'Base property ID': 105875,
#     'Street address': '318-322 Little Bourke Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Penny Blue',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 14}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9653899, -37.81176167]},
#    'properties': {'FIELD1': 81,
#     'Census year': 2015,
#     'Block ID': 66,
#     'Property ID': 109436,
#     'Base property ID': 109436,
#     'Street address': '27-29 Tattersalls Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Section 8 Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9657034, -37.810658]},
#    'properties': {'FIELD1': 82,
#     'Census year': 2015,
#     'Block ID': 76,
#     'Property ID': 589841,
#     'Base property ID': 105749,
#     'Street address': '221 Little Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': "Father's Office",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 170}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9672365, -37.81156167]},
#    'properties': {'FIELD1': 83,
#     'Census year': 2015,
#     'Block ID': 66,
#     'Property ID': 108550,
#     'Base property ID': 108550,
#     'Street address': '213-217 Russell Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Escape City',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 45}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9638158, -37.81135]},
#    'properties': {'FIELD1': 84,
#     'Census year': 2015,
#     'Block ID': 85,
#     'Property ID': 102596,
#     'Base property ID': 102596,
#     'Street address': '22 Drewery Place',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Sister Bellas',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9699175, -37.81784465]},
#    'properties': {'FIELD1': 85,
#     'Census year': 2015,
#     'Block ID': 6,
#     'Property ID': 578324,
#     'Base property ID': 573333,
#     'Street address': '2 Swanston Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Transit Cocktail Lounge',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9655966, -37.8166033]},
#    'properties': {'FIELD1': 86,
#     'Census year': 2015,
#     'Block ID': 25,
#     'Property ID': 101789,
#     'Base property ID': 101789,
#     'Street address': '252-254 Flinders Lane',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': "Hell's Kitchen",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9676479, -37.81246709]},
#    'properties': {'FIELD1': 87,
#     'Census year': 2015,
#     'Block ID': 56,
#     'Property ID': 108538,
#     'Base property ID': 108538,
#     'Street address': '163-169 Russell Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Eden Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 150}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9676479, -37.81246709]},
#    'properties': {'FIELD1': 88,
#     'Census year': 2015,
#     'Block ID': 56,
#     'Property ID': 108538,
#     'Base property ID': 108538,
#     'Street address': '163-169 Russell Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Eden Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 50}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9611929, -37.81283306]},
#    'properties': {'FIELD1': 89,
#     'Census year': 2015,
#     'Block ID': 64,
#     'Property ID': 105705,
#     'Base property ID': 105705,
#     'Street address': '383-387 Lonsdale Street',
#     'CLUE small area': 'Melbourne (CBD)',
#     'Trading name': 'Niagara Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9640121, -37.81488174]},
#    'properties': {'FIELD1': 90,
#     'Census year': 2015,
#     'Block ID': 45,
# ...
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 36}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9309535, -37.82210926]},
#    'properties': {'FIELD1': 172,
#     'Census year': 2015,
#     'Block ID': 774,
#     'Property ID': 600431,
#     'Base property ID': 600431,
#     'Street address': '816 Lorimer Street',
#     'CLUE small area': 'Port Melbourne',
#     'Trading name': 'Underbridge Sports Bar & Cafe',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 52}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9309535, -37.82210926]},
#    'properties': {'FIELD1': 173,
#     'Census year': 2015,
#     'Block ID': 774,
#     'Property ID': 600431,
#     'Base property ID': 600431,
#     'Street address': '816 Lorimer Street',
#     'CLUE small area': 'Port Melbourne',
#     'Trading name': 'Underbridge Sports Bar & Cafe',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9503336, -37.82409303]},
#    'properties': {'FIELD1': 174,
#     'Census year': 2015,
#     'Block ID': 804,
#     'Property ID': 110988,
#     'Base property ID': 110988,
#     'Street address': '29-65 South Wharf Promenade',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Munich Brau Haus',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 250}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9503336, -37.82409303]},
#    'properties': {'FIELD1': 175,
#     'Census year': 2015,
#     'Block ID': 804,
#     'Property ID': 110988,
#     'Base property ID': 110988,
#     'Street address': '29-65 South Wharf Promenade',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Munich Brau Haus',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 150}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9586604, -37.82312164]},
#    'properties': {'FIELD1': 176,
#     'Census year': 2015,
#     'Block ID': 803,
#     'Property ID': 111175,
#     'Base property ID': 110477,
#     'Street address': '8 Whiteman Street',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Lumia Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 110}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9586604, -37.82312164]},
#    'properties': {'FIELD1': 177,
#     'Census year': 2015,
#     'Block ID': 803,
#     'Property ID': 111175,
#     'Base property ID': 110477,
#     'Street address': '8 Whiteman Street',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Lumia Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9645668, -37.82166549]},
#    'properties': {'FIELD1': 178,
#     'Census year': 2015,
#     'Block ID': 801,
#     'Property ID': 559161,
#     'Base property ID': 559161,
#     'Street address': '3-7 Riverside Quay',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Belgian Beer Cafe Melbourne',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 150}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9645668, -37.82166549]},
#    'properties': {'FIELD1': 179,
#     'Census year': 2015,
#     'Block ID': 801,
#     'Property ID': 559161,
#     'Base property ID': 559161,
#     'Street address': '3-7 Riverside Quay',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Belgian Beer Cafe Melbourne',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 60}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9662623, -37.82066923]},
#    'properties': {'FIELD1': 180,
#     'Census year': 2015,
#     'Block ID': 753,
#     'Property ID': 110606,
#     'Base property ID': 110380,
#     'Street address': '3 Southgate Avenue',
#     'CLUE small area': 'Southbank',
#     'Trading name': "P J O'Briens Irish Pub & Side Bar",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 150}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9662623, -37.82066923]},
#    'properties': {'FIELD1': 181,
#     'Census year': 2015,
#     'Block ID': 753,
#     'Property ID': 110323,
#     'Base property ID': 110380,
#     'Street address': '1 Southgate Avenue',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Aria Bar & Lounge',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 63}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9682264, -37.82094188]},
#    'properties': {'FIELD1': 182,
#     'Census year': 2015,
#     'Block ID': 752,
#     'Property ID': 108653,
#     'Base property ID': 110733,
#     'Street address': '100 St Kilda Road',
#     'CLUE small area': 'Southbank',
#     'Trading name': 'Mezz Bar',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 20}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9814116, -37.84752524]},
#    'properties': {'FIELD1': 183,
#     'Census year': 2015,
#     'Block ID': 724,
#     'Property ID': 106798,
#     'Base property ID': 106798,
#     'Street address': '557 St Kilda Road',
#     'CLUE small area': 'Melbourne (Remainder)',
#     'Trading name': 'Village Melbourne - Garden, Arbor, Bistro & Terrace',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 140}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9814116, -37.84752524]},
#    'properties': {'FIELD1': 184,
#     'Census year': 2015,
#     'Block ID': 724,
#     'Property ID': 106798,
#     'Base property ID': 106798,
#     'Street address': '557 St Kilda Road',
#     'CLUE small area': 'Melbourne (Remainder)',
#     'Trading name': 'Village Melbourne - Garden, Arbor, Bistro & Terrace',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 800}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9482732, -37.80844822]},
#    'properties': {'FIELD1': 185,
#     'Census year': 2015,
#     'Block ID': 427,
#     'Property ID': 108867,
#     'Base property ID': 108867,
#     'Street address': '515-523 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Royal Mail Hotel On Spencer',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9482732, -37.80844822]},
#    'properties': {'FIELD1': 186,
#     'Census year': 2015,
#     'Block ID': 427,
#     'Property ID': 108867,
#     'Base property ID': 108867,
#     'Street address': '515-523 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Royal Mail Hotel On Spencer',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 15}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9508616, -37.81114228]},
#    'properties': {'FIELD1': 187,
#     'Census year': 2015,
#     'Block ID': 101,
#     'Property ID': 108949,
#     'Base property ID': 108949,
#     'Street address': '396-400 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Carron Tavern (Spencer Street) Pty Ltd',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 200}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9508616, -37.81114228]},
#    'properties': {'FIELD1': 188,
#     'Census year': 2015,
#     'Block ID': 101,
#     'Property ID': 108949,
#     'Base property ID': 108949,
#     'Street address': '396-400 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Carron Tavern (Spencer Street) Pty Ltd',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 45}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.952636, -37.80890193]},
#    'properties': {'FIELD1': 189,
#     'Census year': 2015,
#     'Block ID': 439,
#     'Property ID': 102962,
#     'Base property ID': 102962,
#     'Street address': '78-86 Dudley Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Witches In Britches Pty Ltd',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 350}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9510475, -37.80556768]},
#    'properties': {'FIELD1': 190,
#     'Census year': 2015,
#     'Block ID': 424,
#     'Property ID': 109710,
#     'Base property ID': 109710,
#     'Street address': '315 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'The Bodega',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 20}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9510475, -37.80556768]},
#    'properties': {'FIELD1': 191,
#     'Census year': 2015,
#     'Block ID': 424,
#     'Property ID': 109710,
#     'Base property ID': 109710,
#     'Street address': '315 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'The Bodega',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.955498, -37.80666721]},
#    'properties': {'FIELD1': 192,
#     'Census year': 2015,
#     'Block ID': 435,
#     'Property ID': 107481,
#     'Base property ID': 107481,
#     'Street address': '65-67 Peel Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'The Drunken Poet Pty Ltd',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 35}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.955498, -37.80666721]},
#    'properties': {'FIELD1': 193,
#     'Census year': 2015,
#     'Block ID': 435,
#     'Property ID': 107481,
#     'Base property ID': 107481,
#     'Street address': '65-67 Peel Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'The Drunken Poet Pty Ltd',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9492503, -37.80956913]},
#    'properties': {'FIELD1': 194,
#     'Census year': 2015,
#     'Block ID': 441,
#     'Property ID': 108856,
#     'Base property ID': 108856,
#     'Street address': '475-477 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Hotel Spencer Bar & Dining Room',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 90}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9492503, -37.80956913]},
#    'properties': {'FIELD1': 195,
#     'Census year': 2015,
#     'Block ID': 441,
#     'Property ID': 108856,
#     'Base property ID': 108856,
#     'Street address': '475-477 Spencer Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Hotel Spencer Bar & Dining Room',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 12}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9494595, -37.80539883]},
#    'properties': {'FIELD1': 196,
#     'Census year': 2015,
#     'Block ID': 423,
#     'Property ID': 109721,
#     'Base property ID': 109721,
#     'Street address': '361-365 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Three Crowns Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 91}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9494595, -37.80539883]},
#    'properties': {'FIELD1': 197,
#     'Census year': 2015,
#     'Block ID': 423,
#     'Property ID': 109721,
#     'Base property ID': 109721,
#     'Street address': '361-365 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Three Crowns Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 40}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9510931, -37.80556778]},
#    'properties': {'FIELD1': 198,
#     'Census year': 2015,
#     'Block ID': 424,
#     'Property ID': 109709,
#     'Base property ID': 109709,
#     'Street address': '313 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': "Clever Polly's",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9510931, -37.80556778]},
#    'properties': {'FIELD1': 199,
#     'Census year': 2015,
#     'Block ID': 424,
#     'Property ID': 109709,
#     'Base property ID': 109709,
#     'Street address': '313 Victoria Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': "Clever Polly's",
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Outdoor',
#     'Number of seats': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9542537, -37.80781408]},
#    'properties': {'FIELD1': 200,
#     'Census year': 2015,
#     'Block ID': 437,
#     'Property ID': 110111,
#     'Base property ID': 110111,
#     'Street address': '333-337 William Street',
#     'CLUE small area': 'West Melbourne (Residential)',
#     'Trading name': 'Royal Standard Hotel',
#     'Industry (ANZSIC4) code': 4520,
#     'Industry (ANZSIC4) description': 'Pubs, Taverns and Bars',
#     'Seating type': 'Seats - Indoor',
#     'Number of seats': 150}}]}

# %%
collection.find_one({"features.properties.Gallery Name" : { "$exists" : True }}, {"_id":0})
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9654639, -37.80776441]},
#    'properties': {'Gallery Name': 'Old Melbourne Gaol Crime'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96883730000002, -37.82199473]},
#    'properties': {'Gallery Name': 'Victorian Arts Centre'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.969899, -37.81748314]},
#    'properties': {'Gallery Name': 'The Ian Potter Centre: NGV Australia'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9839701, -37.81886627]},
#    'properties': {'Gallery Name': 'Thoroughbred Racing Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9484967, -37.82137443]},
#    'properties': {'Gallery Name': 'Fox Classic Car Collection'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9540279, -37.81338543]},
#    'properties': {'Gallery Name': 'Koorie Heritage Trust Inc'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96907040000002, -37.81761073]},
#    'properties': {'Gallery Name': 'Australian Centre For The Moving Image (ACMI)'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.966812, -37.816711]},
#    'properties': {'Gallery Name': 'Blindside Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.970033, -37.815715000000004]},
#    'properties': {'Gallery Name': 'Flinders Lane Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.969861, -37.815758]},
#    'properties': {'Gallery Name': 'Mailbox Art Space'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.95545790000003, -37.8125865]},
#    'properties': {'Gallery Name': 'RMIT Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96402, -37.813891999999996]},
#    'properties': {'Gallery Name': 'Neon Parc'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.962224, -37.812816]},
#    'properties': {'Gallery Name': 'Outre Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96889, -37.816047999999995]},
#    'properties': {'Gallery Name': 'Anna Schwartz Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.97308, -37.81473]},
#    'properties': {'Gallery Name': 'ARC ONE Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.971399, -37.811609000000004]},
#    'properties': {'Gallery Name': 'Gallery Funaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.97052, -37.814921999999996]},
#    'properties': {'Gallery Name': 'Lesley Kehoe Galleries'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.964823, -37.815775]},
#    'properties': {'Gallery Name': 'SpACE@Collins'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.97133, -37.813133]},
#    'properties': {'Gallery Name': 'Tolarno Galleries'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.9592075, -37.81837410000001]},
#    'properties': {'Gallery Name': 'Immigration Museum'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96892780000002, -37.822594200000005]},
#    'properties': {'Gallery Name': 'National Gallery of Victoria'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9585509, -37.7982687]},
#    'properties': {'Gallery Name': 'The Dax Centre'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.97088469999997, -37.816955799999995]},
#    'properties': {'Gallery Name': 'Fortyfivedownstairs Inc'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [144.96738380000002, -37.8134924]},
#    'properties': {'Gallery Name': 'Pieces of Eight Gallery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [144.9523872, -37.8165815]},
#    'properties': {'Gallery Name': 'Magnet Galleries Melbourne'}}]}
